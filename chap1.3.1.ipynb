# %% [markdown]
# ## chap 1.3.1

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def pltImage(img):
    plt.imshow(img)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
img = cv2.imread('dog.jpg')
px = img[100,100]
print (px)
# Out:
# [ 27  55 119]

# %%
pltImage(img)
